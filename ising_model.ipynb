# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import renormalization as rg

# %% [markdown]
# # Initialize a renormalization group object

# %%
RG = rg.RenormalizationGroup(decimation=2, dimension=2)

# %% [markdown]
# # Renormalizaiton-group flow

# %%
j = .1
h = 0.001

RG.flow(j, h, 30)
# Out:
# k,   J         H
# ------------------
# 0    0.1      0.001
# 1    0.038976165254553      0.0027598944568044403
# 2    0.006051379114676125      0.006373410674020724
# 3    0.00014636733471146135      0.0130552377229467
# 4    8.546031721179403e-08      0.026125748446172797
# 5    2.886579864025407e-14      0.05225151468932451
# 6    0.0      0.10450302937866093
# 7    0.0      0.2090060587573219
# 8    0.0      0.4180121175146438
# 9    1.1102230246251565e-16      0.8360242350292876
# 10    0.0      1.6720484700585756
# 11    4.440892098500626e-16      3.344096940117151
# 12    0.0      6.688193880234303
# 13    0.0      13.376387760468607
# 14    0.0      26.752775520937213
# 15    0.0      53.505551041874426
# 16    0.0      107.01110208374885
# 17    0.0      214.0222041674977
# 18    0.0      428.0444083349954
# 19    0.0      856.0888166699908
# 20    0.0      1712.1776333399816
# 21    0.0      3424.3552666799633
# 22    0.0      6848.710533359927
# 23    0.0      13697.421066719853
# 24    0.0      27394.842133439706
# 25    0.0      54789.68426687941
# 26    0.0      109579.36853375882
# 27    0.0      219158.73706751765
# 28    0.0      438317.4741350353
# 29    0.0      876634.9482700706
# 30    0.0      1753269.8965401412

# %% [markdown]
# # Calculate and plot densities

# %%
h = 0
temperature, density = RG.densities(h)

# %%
plt.style.use('classic')
fig = plt.figure(figsize=(8, 6))
fig.set_facecolor('none')

lw = 2.5
fs = 20
plt.rc('lines', linewidth=lw)
plt.rc('axes', linewidth=lw)

ax = plt.subplot(111)
ax.plot(temperature, density[::,1], label=f'H = {h}')
ax.tick_params(axis="both", direction="in", left=True,
               width=lw, length=4, labelsize=fs)
ax.set_xlabel(r"Temperature $\mathrm{1/J}$", fontsize=fs)
ax.set_ylabel(r"Interaction Energy Density $\mathrm{\langle s_i s_j \rangle}$", fontsize=fs)
ax.legend()
plt.tight_layout()
#plt.savefig("densities", dpi=300)
plt.show()

# %%
plt.style.use('classic')
fig = plt.figure(figsize=(8, 6))
fig.set_facecolor('none')

lw = 2.5
fs = 20
plt.rc('lines', linewidth=lw)
plt.rc('axes', linewidth=lw)

ax = plt.subplot(111)
ax.plot(temperature, density[::,2], label=f'H = {h}')
ax.tick_params(axis="both", direction="in", left=True,
               width=lw, length=4, labelsize=fs)
ax.set_xlabel(r"Temperature $\mathrm{1/J}$", fontsize=fs)
ax.set_ylabel(r"Magnetization $\mathrm{\langle s_i \rangle}$", fontsize=fs)
ax.legend()
plt.tight_layout()
#plt.savefig("densities", dpi=300)
plt.show()
